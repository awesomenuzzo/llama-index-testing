# %%
# %pip install llama_index
# %pip install ragas
# %pip install unstructured
# Out:
# Requirement already satisfied: llama_index in ./venv/lib/python3.12/site-packages (0.11.9)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.1 in ./venv/lib/python3.12/site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in ./venv/lib/python3.12/site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.9 in ./venv/lib/python3.12/site-packages (from llama_index) (0.11.9)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in ./venv/lib/python3.12/site-packages (from llama_index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in ./venv/lib/python3.12/site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in ./venv/lib/python3.12/site-packages (from llama_index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.3 in ./venv/lib/python3.12/site-packages (from llama_index) (0.2.6)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in ./venv/lib/python3.12/site-packages (from llama_index) (0.2.1)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in ./venv/lib/python3.12/site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in ./venv/lib/python3.12/site-packages (from llama_index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in ./venv/lib/python3.12/site-packages (from llama_index) (0.2.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in ./venv/lib/python3.12/site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in ./venv/lib/python3.12/site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in ./venv/lib/python3.12/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (1.45.0)
# Requirement already satisfied: PyYAML>=6.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (3.10.5)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2024.6.1)
# Requirement already satisfied: httpx in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2.9.1)
# Requirement already satisfied: requests>=2.31.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.9->llama_index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in ./venv/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama_index) (0.0.17)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./venv/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./venv/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.3.0->llama_index) (0.5.5)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama_index) (2024.9.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.11.1)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama_index) (2.6)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (4.4.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.5)
# Requirement already satisfied: idna in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.8)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.9->llama_index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama_index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.9->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.1)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.9->llama_index) (24.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ragas in ./venv/lib/python3.12/site-packages (0.1.18)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from ragas) (1.26.4)
# Requirement already satisfied: datasets in ./venv/lib/python3.12/site-packages (from ragas) (3.0.0)
# Requirement already satisfied: tiktoken in ./venv/lib/python3.12/site-packages (from ragas) (0.7.0)
# Requirement already satisfied: langchain in ./venv/lib/python3.12/site-packages (from ragas) (0.3.0)
# Requirement already satisfied: langchain-core in ./venv/lib/python3.12/site-packages (from ragas) (0.3.0)
# Requirement already satisfied: langchain-community in ./venv/lib/python3.12/site-packages (from ragas) (0.3.0)
# Requirement already satisfied: langchain-openai in ./venv/lib/python3.12/site-packages (from ragas) (0.2.0)
# Requirement already satisfied: openai>1 in ./venv/lib/python3.12/site-packages (from ragas) (1.45.0)
# Requirement already satisfied: pysbd>=0.3.4 in ./venv/lib/python3.12/site-packages (from ragas) (0.3.4)
# Requirement already satisfied: nest-asyncio in ./venv/lib/python3.12/site-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in ./venv/lib/python3.12/site-packages (from ragas) (1.4.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (2.9.1)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./venv/lib/python3.12/site-packages (from openai>1->ragas) (4.12.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.12/site-packages (from datasets->ragas) (3.16.0)
# Requirement already satisfied: pyarrow>=15.0.0 in ./venv/lib/python3.12/site-packages (from datasets->ragas) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in ./venv/lib/python3.12/site-packages (from datasets->ragas) (0.3.8)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from datasets->ragas) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in ./venv/lib/python3.12/site-packages (from datasets->ragas) (2.32.3)
# Requirement already satisfied: xxhash in ./venv/lib/python3.12/site-packages (from datasets->ragas) (3.5.0)
# Requirement already satisfied: multiprocess in ./venv/lib/python3.12/site-packages (from datasets->ragas) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in ./venv/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->ragas) (2024.6.1)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.12/site-packages (from datasets->ragas) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in ./venv/lib/python3.12/site-packages (from datasets->ragas) (0.24.7)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from datasets->ragas) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in ./venv/lib/python3.12/site-packages (from datasets->ragas) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv/lib/python3.12/site-packages (from langchain->ragas) (2.0.34)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in ./venv/lib/python3.12/site-packages (from langchain->ragas) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./venv/lib/python3.12/site-packages (from langchain->ragas) (0.1.120)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./venv/lib/python3.12/site-packages (from langchain->ragas) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.12/site-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./venv/lib/python3.12/site-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./venv/lib/python3.12/site-packages (from langchain-community->ragas) (2.5.2)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.12/site-packages (from tiktoken->ragas) (2024.9.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (1.11.1)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>1->ragas) (3.8)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>1->ragas) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>1->ragas) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->ragas) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>1->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in ./venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>1->ragas) (2.23.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->ragas) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets->ragas) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets->ragas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->datasets->ragas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas->datasets->ragas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (1.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting unstructured
#   Downloading unstructured-0.15.12-py3-none-any.whl.metadata (29 kB)
# Collecting chardet (from unstructured)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-5.3.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: nltk in ./venv/lib/python3.12/site-packages (from unstructured) (3.9.1)
# Collecting tabulate (from unstructured)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.12/site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.12/site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.4.27-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 9.9 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2 in ./venv/lib/python3.12/site-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.9.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.12/site-packages (from unstructured) (4.12.2)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.25.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in ./venv/lib/python3.12/site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in ./venv/lib/python3.12/site-packages (from unstructured) (6.0.0)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in ./venv/lib/python3.12/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.12/site-packages (from nltk->unstructured) (2024.9.11)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->unstructured) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests->unstructured) (2024.8.30)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured)
#   Downloading deepdiff-8.0.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: httpx>=0.27.0 in ./venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (0.27.2)
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mypy-extensions>=1.0.0 in ./venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: nest-asyncio>=1.6.0 in ./venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: packaging>=23.1 in ./venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (24.1)
# Requirement already satisfied: pypdf>=4.0 in ./venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (4.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from unstructured-client->unstructured) (2.9.0.post0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting orderly-set==5.2.2 (from deepdiff>=6.0->unstructured-client->unstructured)
#   Downloading orderly_set-5.2.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.4.0)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.5)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Downloading unstructured-0.15.12-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.7 MB/s eta 0:00:00a 0:00:01
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 11.1 MB/s eta 0:00:00
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 13.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading lxml-5.3.0-cp312-cp312-macosx_10_9_universal2.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 20.5 MB/s eta 0:00:0000:0100:01
# Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 15.3 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.9.7-cp312-cp312-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 18.9 MB/s eta 0:00:0000:0100:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading unstructured_client-0.25.8-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 4.0 MB/s eta 0:00:00
# Downloading deepdiff-8.0.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 7.8 MB/s eta 0:00:00
# Downloading orderly_set-5.2.2-py3-none-any.whl (11 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.0 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.5 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (pyproject.toml) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=c3ce82151b4fe57f298144cebab5c8669d678cbe8613a9e854dc3b66ab3a7357
#   Stored in directory: /Users/awesomenuzzo/Library/Caches/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, tabulate, rapidfuzz, python-magic, python-iso639, orderly-set, olefile, lxml, langdetect, jsonpath-python, emoji, chardet, backoff, requests-toolbelt, python-oxmsg, deepdiff, unstructured-client, unstructured
# Successfully installed backoff-2.2.1 chardet-5.2.0 deepdiff-8.0.1 emoji-2.12.1 filetype-1.2.0 jsonpath-python-1.0.6 langdetect-1.0.9 lxml-5.3.0 olefile-0.47 orderly-set-5.2.2 python-iso639-2024.4.27 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.9.7 requests-toolbelt-1.0.0 tabulate-0.9.0 unstructured-0.15.12 unstructured-client-0.25.8
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
openai.api_key = OPENAI_API_KEY

# %%
import llama_index
import openai
import os.path
import ragas

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
openai.api_key = OPENAI_API_KEY # Sourced from .env file

# %%
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
    Settings,
)

from llama_index.llms.openai import OpenAI

# %%
Settings.llm = OpenAI(model="gpt-4o-mini")

# %%
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader(input_files=["aapl-20220924.html"]).load_data()    
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

# %%
query_engine = index.as_query_engine()
response = query_engine.query("How was AAPLs performance over the period covered by the document?")
print(response)
# Out:
# During the period covered by the document, Apple Inc. experienced an 8% increase in total net sales, amounting to an additional $28.5 billion in 2022 compared to 2021. This growth was primarily driven by higher net sales of iPhone, Services, and Mac. However, the company faced challenges due to unfavorable foreign currency fluctuations relative to the U.S. dollar, which negatively impacted net sales across all products and services.

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.document_loaders import DirectoryLoader

import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/awesomenuzzo/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/awesomenuzzo/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
loader = DirectoryLoader("RAG Docs")
documents = loader.load()

# %%
# generator with openai models
generator_llm = ChatOpenAI(model="gpt-3.5-turbo-16k")
critic_llm = ChatOpenAI(model="gpt-4")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

# generate testset
testset = generator.generate_with_langchain_docs(documents, test_size=10, distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25}, raise_exceptions=False)
# Out:
# ---------------------------------------------------------------------------
# ExceptionInRunner                         Traceback (most recent call last)
# Cell In[60], line 13
#       6 generator = TestsetGenerator.from_langchain(
#       7     generator_llm,
#       8     critic_llm,
#       9     embeddings
#      10 )
#      12 # generate testset
# ---> 13 testset = generator.generate_with_langchain_docs(documents, test_size=10, distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25}, raise_exceptions=False)
#
# File ~/Documents/School/Research/llama-index-testing/venv/lib/python3.12/site-packages/ragas/testset/generator.py:206, in TestsetGenerator.generate_with_langchain_docs(self, documents, test_size, distributions, with_debugging_logs, is_async, raise_exceptions, run_config)
#     204 distributions = distributions or {}
#     205 # chunk documents and add to docstore
# --> 206 self.docstore.add_documents(
#     207     [Document.from_langchain_document(doc) for doc in documents]
#     208 )
#     210 return self.generate(
#     211     test_size=test_size,
#     212     distributions=distributions,
#    (...)
#     216     run_config=run_config,
#     217 )
#
# File ~/Documents/School/Research/llama-index-testing/venv/lib/python3.12/site-packages/ragas/testset/docstore.py:214, in InMemoryDocumentStore.add_documents(self, docs, show_progress)
#     209 # split documents with self.splitter into smaller nodes
#     210 nodes = [
#     211     Node.from_langchain_document(d)
#     212     for d in self.splitter.transform_documents(docs)
#     213 ]
# --> 214 self.add_nodes(nodes, show_progress=show_progress)
#
# File ~/Documents/School/Research/llama-index-testing/venv/lib/python3.12/site-packages/ragas/testset/docstore.py:253, in InMemoryDocumentStore.add_nodes(self, nodes, show_progress)
#     251 results = executor.results()
#     252 if not results:
# --> 253     raise ExceptionInRunner()
#     255 for i, n in enumerate(nodes):
#     256     if i in nodes_to_embed.keys():
#
# ExceptionInRunner: The runner thread which was running the jobs raised an exeception. Read the traceback above to debug it. You can also pass `raise_exceptions=False` incase you want to show only a warning message instead.
